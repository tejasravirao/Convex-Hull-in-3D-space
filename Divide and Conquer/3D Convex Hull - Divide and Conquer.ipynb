# %%
import numpy as np
from scipy.spatial import ConvexHull
file_path = input("Enter a file path to store the generated input: ")
num_points = int(input("Enter the number of points to generate: "))
points = np.random.rand(num_points, 3)*10

input_file = open(file_path, "w+")
for i in range(0, len(points)):
    point = points[i]
    input_file.write(str(point[0])+","+str(point[1])+","+str(point[2])+"\n")
    
input_file.close();

hull = ConvexHull(points)

import matplotlib.pyplot as plt
plt.plot(points[:,0], points[:,1], 'o')
plt.plot(points[hull.vertices,0], points[hull.vertices,1], 'r--', lw=3)
plt.plot(points[hull.vertices[0],0], points[hull.vertices[0],1], 'ro')
plt.show()
# Out:
# Enter a file path to store the generated input: /Users/anandb/Documents/OneDrive - The University of Texas at Dallas/Academics/Computational-Geometry/project/java_code/input/8
# Enter the number of points to generate: 1024

# %%
f= open("/Users/anandb/Documents/OneDrive - The University of Texas at Dallas/Academics/Computational-Geometry/project/java_code/output/output.txt","r")
data = list()
sources = list()
for line in f:
    src = line[:-1].split("\t")[0]
    dest = line[:-1].split("\t")[1]
    data.append([
        (float(src.split(",")[0]), float(src.split(",")[1]), float(src.split(",")[2])),
        (float(dest.split(",")[0]), float(dest.split(",")[1]), float(dest.split(",")[2]))
    ])
    sources.append([float(src.split(",")[0]), float(src.split(",")[1]), float(src.split(",")[2])]);
f.close()

import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10, 10), dpi=100)
ax = fig.add_subplot(111, projection='3d')

ax.scatter(points[:,0], points[:,1], points[:,2], c='b', marker='o')
sources = np.array(sources)
ax.scatter(sources[:,0], sources[:,1], sources[:,2], c='r', marker='^')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

for i in range(len(data)):
    ax.plot(xs=[data[i][0][0], data[i][1][0]], ys=[data[i][0][1], data[i][1][1]],zs=[data[i][0][2], data[i][1][2]])
plt.show()
